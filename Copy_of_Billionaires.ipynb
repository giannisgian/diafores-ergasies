# %% [markdown]
# <a href="https://colab.research.google.com/github/giannisgian/diafores-ergasies/blob/main/Copy_of_Billionaires.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Classwork Δισεκατομμυριούχοι

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## 1) Διαβάστε το αρχείο `richpeople.xlsx` και προσέξτε ότι είναι ένα Excel αρχείο, οπότε πρέπει να το διαβάσουμε χρησιμοποιώντας το  `read_excel` αντί για το `read_csv`.

# %%
df= pd.read_excel("https://github.com/datajour-gr/Data_journalism/blob/master/week5/Homework/richpeople.xlsx?raw=true")

# %% [markdown]
# ## 2) Ελέγξτε τα data
#
# Πόσα κελιά έχει και πόσες στήλες? Τι είδος είναι τα δεδομένα?

# %%
df.shape
# Out:
# (2614, 30)

# %%
df.dtypes
# Out:
# year                         int64
# name                        object
# rank                         int64
# citizenship                 object
# countrycode                 object
# networthusbillion          float64
# selfmade                    object
# typeofwealth                object
# gender                      object
# age                        float64
# industry                    object
# IndustryAggregates          object
# region                      object
# north                        int64
# politicalconnection        float64
# founder                      int64
# generationofinheritance     object
# sector                      object
# company                     object
# companytype                 object
# relationshiptocompany       object
# foundingdate               float64
# gdpcurrentus               float64
# sourceofwealth              object
# notes                       object
# notes2                      object
# source                      object
# source_2                    object
# source_3                    object
# source_4                    object
# dtype: object

# %% [markdown]
# ## 3) Ποιοι είναι οι 10 πιο πλούσιοι δισεκατομμυριούχοι? Χρησιμοποιήστε το  `networthusbillion` column.

# %%
df.sort_values(by='networthusbillion', ascending = False)[:10]
# Out:
#       year              name  rank    citizenship countrycode  \
# 284   2014        Bill Gates     1  United States         USA
# 348   2014  Carlos Slim Helu     2         Mexico         MEX
# 124   2014    Amancio Ortega     3          Spain         ESP
# 283   2001        Bill Gates     1  United States         USA
# 2491  2014    Warren Buffett     4  United States         USA
# 1377  2014     Larry Ellison     5  United States         USA
# 509   2014        David Koch     6  United States         USA
# 381   2014      Charles Koch     6  United States         USA
# 2185  2014   Sheldon Adelson     8  United States         USA
# 429   2014    Christy Walton     9  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 284                76.0  self-made       founder non-finance    male  58.0
# 348                72.0  self-made  privatized and resources    male  74.0
# 124                64.0  self-made       founder non-finance    male  77.0
# 283                58.7  self-made       founder non-finance    male  45.0
# 2491               58.2  self-made       founder non-finance    male  83.0
# 1377               48.0  self-made       founder non-finance    male  69.0
# 509                40.0  inherited                 inherited    male  73.0
# 381                40.0  inherited                 inherited    male  78.0
# 2185               38.0  self-made         self-made finance    male  80.0
# 429                36.7  inherited                 inherited  female  59.0
#
#       ... relationshiptocompany foundingdate  gdpcurrentus  \
# 284   ...               founder       1975.0           NaN
# 348   ...               founder       1990.0           NaN
# 124   ...               founder       1975.0           NaN
# 283   ...               founder       1975.0  1.062180e+13
# 2491  ...               founder       1839.0           NaN
# 1377  ...               founder       1977.0           NaN
# 509   ...              relation       1940.0           NaN
# 381   ...              relation       1940.0           NaN
# 2185  ...               founder       1952.0           NaN
# 429   ...              relation       1962.0           NaN
#
#           sourceofwealth                  notes  notes2  \
# 284            Microsoft                    NaN     NaN
# 348              telecom                    NaN     NaN
# 124               retail                    NaN     NaN
# 283                  NaN                    NaN     NaN
# 2491  Berkshire Hathaway                    NaN     NaN
# 1377              Oracle                    NaN     NaN
# 509          diversified  inherited from father     NaN
# 381          diversified  inherited from father     NaN
# 2185             casinos                    NaN     NaN
# 429             Wal-Mart                  widow     NaN
#
#                                                  source  \
# 284           http://www.forbes.com/profile/bill-gates/
# 348   http://www.ozy.com/provocateurs/carlos-slims-w...
# 124       http://www.forbes.com/profile/amancio-ortega/
# 283           http://www.forbes.com/profile/bill-gates/
# 2491  http://www.forbes.com/lists/2009/10/billionair...
# 1377       http://www.forbes.com/profile/larry-ellison/
# 509   http://www.kochind.com/About_Koch/History_Time...
# 381   http://www.kochind.com/About_Koch/History_Time...
# 2185     http://www.forbes.com/profile/sheldon-adelson/
# 429       http://www.forbes.com/profile/christy-walton/
#
#                                                source_2 source_3 source_4
# 284                                                 NaN      NaN      NaN
# 348                                                 NaN      NaN      NaN
# 124                                                 NaN      NaN      NaN
# 283                                                 NaN      NaN      NaN
# 2491  http://www.forbes.com/companies/berkshire-hath...      NaN      NaN
# 1377  http://www.businessinsider.com/how-larry-ellis...      NaN      NaN
# 509                                                 NaN      NaN      NaN
# 381                                                 NaN      NaN      NaN
# 2185  http://lasvegassun.com/news/1996/nov/26/rat-pa...      NaN      NaN
# 429                                                 NaN      NaN      NaN
#
# [10 rows x 30 columns]

# %%
df.sort_values(by='sourceofwealth', ascending = False)[:10]
# Out:
#       year                  name  rank    citizenship countrycode  \
# 2436  2014       Vincent McMahon  1372  United States         USA
# 1958  2014          Remo Ruffini  1210          Italy         ITA
# 1884  2014         Pierre Castel   166         France         FRA
# 117   2014          Aloys Wobben   408        Germany         DEU
# 292   2014           Bob Parsons   931  United States         USA
# 1493  2014           Liu Zhenguo  1442          China         CHN
# 1889  2014      Pierre Papillaud  1092         France         FRA
# 754   2014           Gabe Newell  1372  United States         USA
# 1760  2014      Nicholas Woodman  1284  United States         USA
# 1283  2014  Kavitark Ram Shriram   973  United States         USA
#
#       networthusbillion   selfmade              typeofwealth gender   age  \
# 2436                1.2  inherited                 inherited   male  68.0
# 1958                1.4  self-made                 executive   male  52.0
# 1884                8.0  self-made       founder non-finance   male  87.0
# 117                 3.7  self-made  privatized and resources   male  62.0
# 292                 1.9  self-made       founder non-finance   male  63.0
# 1493                1.2  self-made                 executive   male  49.0
# 1889                1.6  self-made  privatized and resources   male  78.0
# 754                 1.2  self-made       founder non-finance   male  51.0
# 1760                1.3  self-made       founder non-finance   male  38.0
# 1283                1.9  self-made         self-made finance   male  57.0
#
#       ... relationshiptocompany foundingdate gdpcurrentus  \
# 2436  ...              relation       1952.0          NaN
# 1958  ...                 owner       1954.0          NaN
# 1884  ...               founder       1949.0          NaN
# 117   ...               founder       1984.0          NaN
# 292   ...               founder       1997.0          NaN
# 1493  ...         Vice Chairman       2001.0          NaN
# 1889  ...               founder       1990.0          NaN
# 754   ...               founder       1996.0          NaN
# 1760  ...               founder       2002.0          NaN
# 1283  ...              investor       1998.0          NaN
#
#                sourceofwealth                                       notes  \
# 2436                wrestling  inherited from father (Vincent McMahon Sr)
# 1958           winter jackets                                         NaN
# 1884                     wine                                         NaN
# 117             wind turbines                                         NaN
# 292               web hosting                                         NaN
# 1493  water treatment systems                                         NaN
# 1889                    water                                         NaN
# 754                videogames                                         NaN
# 1760            video cameras                                         NaN
# 1283  venture capital, Google                                         NaN
#
#       notes2                                             source  \
# 2436     NaN         http://en.wikipedia.org/wiki/Vince_McMahon
# 1958     NaN        http://www.forbes.com/profile/remo-ruffini/
# 1884     NaN       http://www.forbes.com/profile/pierre-castel/
# 117      NaN          http://de.wikipedia.org/wiki/Aloys_Wobben
# 292      NaN           http://en.wikipedia.org/wiki/Bob_Parsons
# 1493     NaN         http://www.forbes.com/profile/liu-zhenguo/
# 1889     NaN  http://www.forbes.com/profile/pierre-papillaud-1/
# 754      NaN           http://en.wikipedia.org/wiki/Gabe_Newell
# 1760     NaN          http://en.wikipedia.org/wiki/Nick_Woodman
# 1283     NaN           http://en.wikipedia.org/wiki/Ram_Shriram
#
#                                                source_2  \
# 2436    http://en.wikipedia.org/wiki/Vince_McMahon,_Sr.
# 1958  http://www.telegraph.co.uk/luxury/womens-style...
# 1884  http://www.lemonde.fr/argent/article/2013/06/1...
# 117   https://web.archive.org/web/20091214221844/htt...
# 292          http://www.forbes.com/profile/bob-parsons/
# 1493                                                NaN
# 1889  http://investing.businessweek.com/research/sto...
# 754          http://www.forbes.com/profile/gabe-newell/
# 1760                 http://en.wikipedia.org/wiki/GoPro
# 1283  http://www.bloomberg.com/research/stocks/priva...
#
#                                                source_3 source_4
# 2436     http://www.forbes.com/profile/vincent-mcmahon/      NaN
# 1958                                                NaN      NaN
# 1884                                                NaN      NaN
# 117                                                 NaN      NaN
# 292   Go Daddy exec, wife give back in big way The A...      NaN
# 1493                                                NaN      NaN
# 1889                                                NaN      NaN
# 754   'Half-Life 2' gets Valve's full attentionBelle...      NaN
# 1760    http://www.forbes.com/profile/nicholas-woodman/      NaN
# 1283                                                NaN      NaN
#
# [10 rows x 30 columns]

# %%
telecom= df[df['sourceofwealth']=='telecom']

# %%
df[df['sourceofwealth'].str.contains('telecom',na=False)][df['countrycode'] == "USA"]['networthusbillion'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 2.025

# %%
df[df['sourceofwealth'].str.contains('telecom', na=False)]
# Out:
#       year                   name  rank     citizenship countrycode  \
# 71    2014      Alexander Knaster   828   United States         USA
# 87    2014       Alexei Kuzmichev   147          Russia         RUS
# 112   2014        Alisher Usmanov    40          Russia         RUS
# 137   2014        Ananda Krishnan   100        Malaysia         MYS
# 153   2014         Andrei Kosogov  1046          Russia         RUS
# 155   2014         Andrei Kuzyaev  1442          Russia         RUS
# 348   2014       Carlos Slim Helu     2          Mexico         MEX
# 450   2014            Craig McCaw   988   United States         USA
# 531   2014          Denis O'Brien   234         Ireland         IRL
# 694   2014         Farhad Moshiri   580  United Kingdom         GBR
# 805   2014            German Khan   100          Russia         RUS
# 824   2014           Gleb Fetisov  1210          Russia         RUS
# 1070  2014            Jan Kulczyk   430          Poland         POL
# 1311  2014           Kenny Troutt  1284   United States         USA
# 1617  2014          Masayoshi Son    42           Japan         JPN
# 1628  2014      Mehmet Karamehmet  1154          Turkey         TUR
# 1690  2014        Mikhail Fridman    47          Russia         RUS
# 1731  2014            Murat Vargi  1565          Turkey         TUR
# 1740  2014         Naguib Sawiris   609           Egypt         EGY
# 1741  2014           Najib Mikati   520         Lebanon         LBN
# 1790  2014           Onsi Sawiris   731           Egypt         EGY
# 1906  2014             Pyotr Aven   227          Russia         RUS
# 1987  2014             Richard Li   931       Hong Kong         HKG
# 2092  2014           Rostam Azizi  1565        Tanzania         TZA
# 2305  2014           Sunil Mittal   244           India         IND
# 2307  2014         Surin Upatkoon  1284        Thailand         THA
# 2322  2014            Taha Mikati   520         Lebanon         LBN
# 2453  2014  Vladimir Yevtushenkov   141          Russia         RUS
# 2466  2014      Walter Scott, Jr.   580   United States         USA
# 2474  2014              Wang Jing  1210           China         CHN
# 2552  2014            Xavier Niel   162          France         FRA
# 2564  2014      Yasumitsu Shigeta   663           Japan         JPN
#
#       networthusbillion   selfmade              typeofwealth gender   age  \
# 71                  2.1  self-made  privatized and resources   male  55.0
# 87                  8.8  self-made  privatized and resources   male  51.0
# 112                18.6  self-made  privatized and resources   male  60.0
# 137                11.3  self-made       founder non-finance   male  75.0
# 153                 1.7  self-made  privatized and resources   male  52.0
# 155                 1.2  self-made  privatized and resources   male  48.0
# 348                72.0  self-made  privatized and resources   male  74.0
# 450                 1.8  self-made       founder non-finance   male  64.0
# 531                 6.0  self-made  privatized and resources   male  55.0
# 694                 2.9  self-made  privatized and resources   male  58.0
# 805                11.3  self-made  privatized and resources   male  52.0
# 824                 1.4  self-made                 executive   male  47.0
# 1070                3.6  self-made  privatized and resources   male  64.0
# 1311                1.3  self-made       founder non-finance   male  66.0
# 1617               18.4  self-made       founder non-finance   male  56.0
# 1628                1.5  self-made                 executive   male  69.0
# 1690               17.6  self-made  privatized and resources   male  49.0
# 1731                1.0  self-made       founder non-finance   male  66.0
# 1740                2.8  inherited                 inherited   male  59.0
# 1741                3.1  self-made  privatized and resources   male  58.0
# 1790                2.4  self-made       founder non-finance   male  84.0
# 1906                6.1  self-made  privatized and resources   male  58.0
# 1987                1.9  inherited                 inherited   male  47.0
# 2092                1.0  self-made                 executive   male  49.0
# 2305                5.7  self-made       founder non-finance   male  56.0
# 2307                1.3  self-made                 executive   male  64.0
# 2322                3.1  self-made  privatized and resources   male  69.0
# 2453                9.0  self-made  privatized and resources   male  65.0
# 2466                2.9  self-made                 executive   male  82.0
# 2474                1.4  self-made                 executive   male  41.0
# 2552                8.2  self-made       founder non-finance   male  46.0
# 2564                2.6  self-made       founder non-finance   male  49.0
#
#       ...           relationshiptocompany foundingdate gdpcurrentus  \
# 71    ...                         founder       2005.0          NaN
# 87    ...                         founder       1989.0          NaN
# 112   ...                         founder       1999.0          NaN
# 137   ...                         founder       1984.0          NaN
# 153   ...  supervisory board or directors       1989.0          NaN
# 155   ...                         founder       1991.0          NaN
# 348   ...                         founder       1990.0          NaN
# 450   ...                         founder       1987.0          NaN
# 531   ...                         founder       1997.0          NaN
# 694   ...                         founder       1999.0          NaN
# 805   ...                         founder       1989.0          NaN
# 824   ...                           owner       1989.0          NaN
# 1070  ...                         founder       1988.0          NaN
# 1311  ...                         founder       1988.0          NaN
# 1617  ...                     founder/CEO       1981.0          NaN
# 1628  ...                        chairman       1923.0          NaN
# 1690  ...                         founder       1989.0          NaN
# 1731  ...                         founder       1993.0          NaN
# 1740  ...                        relation       1950.0          NaN
# 1741  ...                         founder       1982.0          NaN
# 1790  ...                         founder       1950.0          NaN
# 1906  ...           chairman of the board       1989.0          NaN
# 1987  ...                        relation       1971.0          NaN
# 2092  ...                        investor       1999.0          NaN
# 2305  ...                         founder       1980.0          NaN
# 2307  ...                           owner       1983.0          NaN
# 2322  ...                         founder       1982.0          NaN
# 2453  ...                Chairman/founder       1993.0          NaN
# 2466  ...                      former CEO       1884.0          NaN
# 2474  ...                        chairman       1995.0          NaN
# 2552  ...                         founder       1999.0          NaN
# 2564  ...                         founder       1988.0          NaN
#
#                          sourceofwealth  \
# 71                oil, telecom, banking
# 87                oil, banking, telecom
# 112         steel, telecom, investments
# 137                             telecom
# 153               oil, telecom, banking
# 155   telecom, oil service, real estate
# 348                             telecom
# 450                             telecom
# 531                             telecom
# 694           iron ore, steel, telecoms
# 805               oil, banking, telecom
# 824                    telecom, finance
# 1070                 telecom, oil, beer
# 1311                 telecommunications
# 1617                  internet, telecom
# 1628               telecom, diversified
# 1690              oil, banking, telecom
# 1731                            telecom
# 1740                            telecom
# 1741                            telecom
# 1790              construction, telecom
# 1906              oil, banking, telecom
# 1987                           telecoms
# 2092               telecom, investments
# 2305                            telecom
# 2307       telecoms/lotteries/insurance
# 2322                            telecom
# 2453                            telecom
# 2466              construction, telecom
# 2474                 telecommunications
# 2552                  internet, telecom
# 2564                     mobile telecom
#
#                                                   notes  \
# 71                                                  NaN
# 87                                                  NaN
# 112                                                 NaN
# 137                                                 NaN
# 153                                                 NaN
# 155                                 connected to Lukoil
# 348                                                 NaN
# 450   not only won FCC's lottery for setting up cabl...
# 531   won a mobile phone licence due to payments to ...
# 694                                                 NaN
# 805                                                 NaN
# 824                                                 NaN
# 1070                                                NaN
# 1311                                                NaN
# 1617                                                NaN
# 1628                                                NaN
# 1690                                                NaN
# 1731                                                NaN
# 1740                              inherited from father
# 1741  PM of Lebanon from June 2001 to Feb 2014 and i...
# 1790  Some evidence connected money, but less eviden...
# 1906                                                NaN
# 1987                              inherited from father
# 2092                                                NaN
# 2305                                                NaN
# 2307                                                NaN
# 2322                            PM of Lebanon's brother
# 2453                                   Bashneft scandal
# 2466  Childhood friend of Warren Buffet, sits on Ber...
# 2474                                                NaN
# 2552                                                NaN
# 2564  Had $42 billion in 1999, lost most of it in do...
#
#                                                  notes2  \
# 71                                                  NaN
# 87                                                  NaN
# 112                                                 NaN
# 137                                                 NaN
# 153                                                 NaN
# 155                                                 NaN
# 348                                                 NaN
# 450                                                 NaN
# 531                                                 NaN
# 694                                                 NaN
# 805                                                 NaN
# 824                                                 NaN
# 1070                                                NaN
# 1311                                                NaN
# 1617                                                NaN
# 1628                                                NaN
# 1690                                                NaN
# 1731                                                NaN
# 1740                                                NaN
# 1741                                                NaN
# 1790                                                NaN
# 1906                                                NaN
# 1987                                                NaN
# 2092                                                NaN
# 2305                                                NaN
# 2307                                                NaN
# 2322                                                NaN
# 2453                                                NaN
# 2466                                                NaN
# 2474  involved in Nicaragua projected / some questio...
# 2552                                                NaN
# 2564                                                NaN
#
#                                                  source  \
# 71       http://en.wikipedia.org/wiki/Alexander_Knaster
# 87        http://en.wikipedia.org/wiki/Alexey_Kuzmichev
# 112                               http://usm-group.com/
# 137        http://en.wikipedia.org/wiki/Ananda_Krishnan
# 153       http://www.forbes.com/profile/andrei-kosogov/
# 155       http://www.forbes.com/profile/andrei-kuzyaev/
# 348   http://www.ozy.com/provocateurs/carlos-slims-w...
# 450            http://en.wikipedia.org/wiki/Craig_McCaw
# 531          http://en.wikipedia.org/wiki/Denis_O'Brien
# 694   http://en.wikipedia.org/wiki/Farhad_Moshiri_(b...
# 805            http://en.wikipedia.org/wiki/German_Khan
# 824         http://www.forbes.com/profile/gleb-fetisov/
# 1070           http://en.wikipedia.org/wiki/Jan_Kulczyk
# 1311        http://www.forbes.com/profile/kenny-troutt/
# 1617         http://en.wikipedia.org/wiki/Masayoshi_Son
# 1628  http://en.wikipedia.org/wiki/Mehmet_Emin_Karam...
# 1690     http://www.forbes.com/profile/mikhail-fridman/
# 1731         http://www.forbes.com/profile/murat-vargi/
# 1740        http://en.wikipedia.org/wiki/Sawiris_Family
# 1741          http://en.wikipedia.org/wiki/Najib_Mikati
# 1790        http://en.wikipedia.org/wiki/Sawiris_Family
# 1906            http://en.wikipedia.org/wiki/Pyotr_Aven
# 1987            http://en.wikipedia.org/wiki/Richard_Li
# 2092        http://www.forbes.com/profile/rostam-azizi/
# 2305          http://en.wikipedia.org/wiki/Sunil_Mittal
# 2307      http://www.forbes.com/profile/surin-upatkoon/
# 2322          http://en.wikipedia.org/wiki/Najib_Mikati
# 2453  http://www.sistema.com/about-sistema/corporate...
# 2466     http://en.wikipedia.org/wiki/Walter_Scott,_Jr.
# 2474         http://www.forbes.com/profile/wang-jing-3/
# 2552           http://en.wikipedia.org/wiki/Xavier_Niel
# 2564   http://www.forbes.com/profile/yasumitsu-shigeta/
#
#                                                source_2  \
# 71     http://www.forbes.com/profile/alexander-knaster/
# 87      http://www.forbes.com/profile/alexei-kuzmichev/
# 112         https://en.wikipedia.org/wiki/Metalloinvest
# 137   http://www.bloomberg.com/research/stocks/priva...
# 153   http://www.bloomberg.com/research/stocks/priva...
# 155          http://www.pfpg.ru/en/company/history.html
# 348                                                 NaN
# 450   http://community.seattletimes.nwsource.com/arc...
# 531   http://www.irishtimes.com/news/ireland/irish-n...
# 694   http://www.bloomberg.com/news/articles/2012-04...
# 805   http://luxatic.com/german-khan-the-oligarch-be...
# 824   Putin's daring stroke abroad masks risks at ho...
# 1070  https://books.google.com/books?id=jP6QAwAAQBAJ...
# 1311  http://www.bloomberg.com/bw/stories/1998-04-19...
# 1617      http://www.softbank.jp/en/corp/about/history/
# 1628  http://en.wikipedia.org/wiki/%C3%87ukurova_Hol...
# 1690  The Autumn Of the Oligarchs The New York Times...
# 1731              http://en.wikipedia.org/wiki/Turkcell
# 1740                                                NaN
# 1741  http://www.bbc.com/news/world-middle-east-1227...
# 1790  http://www.euroasiaindustry.com/article/sawiri...
# 1906  The Autumn Of the Oligarchs The New York Times...
# 1987                                                NaN
# 2092      http://en.wikipedia.org/wiki/Vodacom_Tanzania
# 2305  http://timesofindia.indiatimes.com/topic/Sunil...
# 2307  http://www.intouchcompany.com/as_milestone_en.asp
# 2322  http://www.bbc.com/news/world-middle-east-1227...
# 2453  http://en.wikipedia.org/wiki/Vladimir_Yevtushe...
# 2466    http://en.wikipedia.org/wiki/Kiewit_Corporation
# 2474    http://www.xinwei.com.cn/en/about/about_us.html
# 2552  http://www.ft.com/intl/cms/s/2/22167134-b24a-1...
# 2564                                                NaN
#
#                                                source_3 source_4
# 71    http://www.bloomberg.com/profiles/people/19070...      NaN
# 87    A frosty relationship that failed to thaw; Bas...      NaN
# 112   Russia and the Rams Oligarchy: How the Rams, c...      NaN
# 137      http://www.forbes.com/profile/ananda-krishnan/      NaN
# 153                                                 NaN      NaN
# 155   http://www.bloomberg.com/research/stocks/priva...      NaN
# 348                                                 NaN      NaN
# 450                                                 NaN      NaN
# 531                                                 NaN      NaN
# 694                                                 NaN      NaN
# 805                                                 NaN      NaN
# 824                                                 NaN      NaN
# 1070  Jan Kulczyk, 65, became richest man in Poland ...      NaN
# 1311                                                NaN      NaN
# 1617      http://www.softbank.jp/en/corp/about/message/      NaN
# 1628  http://www.cukurovaholding.com.tr/Kisaca-Cukur...      NaN
# 1690                                                NaN      NaN
# 1731  http://www.bloomberg.com/research/stocks/priva...      NaN
# 1740                                                NaN      NaN
# 1741  Lebanese fund takes Sainsbury's shares to chec...      NaN
# 1790                                                NaN      NaN
# 1906                                                NaN      NaN
# 1987                                                NaN      NaN
# 2092  http://www.thecitizen.co.tz/News/Rostam--Dewji...      NaN
# 2305                                                NaN      NaN
# 2307                                                NaN      NaN
# 2322  Lebanese fund takes Sainsbury's shares to chec...      NaN
# 2453  Zinc giant leads new wave of Russian firms to ...      NaN
# 2466  http://www.bizjournals.com/seattle/morning_cal...      NaN
# 2474  http://www.reuters.com/article/us-china-canal-...      NaN
# 2552                                                NaN      NaN
# 2564                                                NaN      NaN
#
# [32 rows x 30 columns]

# %%
df[df['countrycode'].str.contains('USA', na=False)]
# Out:
#       year                     name  rank    citizenship countrycode  \
# 0     2001      A Jerrold Perenchio   151  United States         USA
# 1     2014     A. Jerrold Perenchio   663  United States         USA
# 10    1996          Abigail Johnson   145  United States         USA
# 11    2001          Abigail Johnson    30  United States         USA
# 12    2014          Abigail Johnson    50  United States         USA
# ...    ...                      ...   ...            ...         ...
# 2534  2014     William Wrigley, Jr.   687  United States         USA
# 2535  2014              Wilma Tisch  1203  United States         USA
# 2536  2014  Winnie Johnson-Marquart   551  United States         USA
# 2537  1996     Winthrop Rockefeller   416  United States         USA
# 2538  2001     Winthrop Rockefeller   421  United States         USA
#
#       networthusbillion   selfmade typeofwealth  gender   age  ...  \
# 0                   3.0  self-made    executive    male  70.0  ...
# 1                   2.6  self-made    executive    male  83.0  ...
# 10                  2.5  inherited    inherited  female  34.0  ...
# 11                  9.1  inherited    inherited  female  39.0  ...
# 12                 17.3  inherited    inherited  female  52.0  ...
# ...                 ...        ...          ...     ...   ...  ...
# 2534                2.5  inherited    inherited    male  50.0  ...
# 2535                1.5  inherited    inherited  female  86.0  ...
# 2536                3.0  inherited    inherited  female  54.0  ...
# 2537                1.0  inherited    inherited    male  47.0  ...
# 2538                1.2  inherited    inherited    male  52.0  ...
#
#         relationshiptocompany foundingdate  gdpcurrentus  \
# 0     former chairman and CEO       1955.0  1.062180e+13
# 1     former chairman and CEO       1955.0           NaN
# 10                   relation       1946.0  8.100200e+12
# 11                   relation       1946.0  1.062180e+13
# 12                   relation       1946.0           NaN
# ...                       ...          ...           ...
# 2534                 relation       1891.0           NaN
# 2535                 relation       1946.0           NaN
# 2536                 relation       1886.0           NaN
# 2537                 relation       1870.0  8.100200e+12
# 2538                 relation       1870.0  1.062180e+13
#
#              sourceofwealth                                           notes  \
# 0                       NaN  represented Marlon Brando and Elizabeth Taylor
# 1     television, Univision  represented Marlon Brando and Elizabeth Taylor
# 10                      NaN                                  3rd generation
# 11                      NaN                                  3rd generation
# 12         money management                                  3rd generation
# ...                     ...                                             ...
# 2534            chewing gum                               fourth generation
# 2535            diversified                                           widow
# 2536      cleaning products                                  5th generation
# 2537                    NaN                                  3rd generation
# 2538                    NaN                                  3rd generation
#
#                 notes2                                             source  \
# 0                  NaN       http://en.wikipedia.org/wiki/Jerry_Perenchio
# 1                  NaN       http://en.wikipedia.org/wiki/Jerry_Perenchio
# 10    no male siblings   http://en.wikipedia.org/wiki/Edward_Johnson,_III
# 11    no male siblings   http://en.wikipedia.org/wiki/Edward_Johnson,_III
# 12    no male siblings   http://en.wikipedia.org/wiki/Edward_Johnson,_III
# ...                ...                                                ...
# 2534               NaN  http://en.wikipedia.org/wiki/William_Wrigley,_Jr.
# 2535               NaN         http://www.forbes.com/profile/wilma-tisch/
# 2536               NaN  http://en.wikipedia.org/wiki/Herbert_Fisk_John...
# 2537               NaN  Agency celebrates 50th with Rockefeller tribut...
# 2538               NaN  Agency celebrates 50th with Rockefeller tribut...
#
#                                                source_2  \
# 0     http://www.forbes.com/profile/a-jerrold-perenc...
# 1     http://www.forbes.com/profile/a-jerrold-perenc...
# 10    https://www.fidelity.com/about-fidelity/our-he...
# 11    https://www.fidelity.com/about-fidelity/our-he...
# 12    https://www.fidelity.com/about-fidelity/our-he...
# ...                                                 ...
# 2534  Wrigley son best known for his bold career mov...
# 2535                                                NaN
# 2536      http://www.forbes.com/profile/h-fisk-johnson/
# 2537                                                NaN
# 2538                                                NaN
#
#                                                source_3 source_4
# 0     COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 1     COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 10                                                  NaN      NaN
# 11                                                  NaN      NaN
# 12                                                  NaN      NaN
# ...                                                 ...      ...
# 2534                                                NaN      NaN
# 2535                                                NaN      NaN
# 2536   http://www.scjohnson.com/en/company/history.aspx      NaN
# 2537                                                NaN      NaN
# 2538                                                NaN      NaN
#
# [903 rows x 30 columns]

# %%
df[df['sourceofwealth'].str.contains('telecom', na=False)]['networthusbillion']
# Out:
# 71       2.1
# 87       8.8
# 112     18.6
# 137     11.3
# 153      1.7
# 155      1.2
# 348     72.0
# 450      1.8
# 531      6.0
# 694      2.9
# 805     11.3
# 824      1.4
# 1070     3.6
# 1311     1.3
# 1617    18.4
# 1628     1.5
# 1690    17.6
# 1731     1.0
# 1740     2.8
# 1741     3.1
# 1790     2.4
# 1906     6.1
# 1987     1.9
# 2092     1.0
# 2305     5.7
# 2307     1.3
# 2322     3.1
# 2453     9.0
# 2466     2.9
# 2474     1.4
# 2552     8.2
# 2564     2.6
# Name: networthusbillion, dtype: float64

# %%
df[df['sourceofwealth'].str.contains('telecom', na=False)]['networthusbillion'].sum()
# Out:
# 234.00000000000006

# %%
df[df['sourceofwealth'].str.contains('telecom', na=False)]
# Out:
#       year                   name  rank     citizenship countrycode  \
# 71    2014      Alexander Knaster   828   United States         USA
# 87    2014       Alexei Kuzmichev   147          Russia         RUS
# 112   2014        Alisher Usmanov    40          Russia         RUS
# 137   2014        Ananda Krishnan   100        Malaysia         MYS
# 153   2014         Andrei Kosogov  1046          Russia         RUS
# 155   2014         Andrei Kuzyaev  1442          Russia         RUS
# 348   2014       Carlos Slim Helu     2          Mexico         MEX
# 450   2014            Craig McCaw   988   United States         USA
# 531   2014          Denis O'Brien   234         Ireland         IRL
# 694   2014         Farhad Moshiri   580  United Kingdom         GBR
# 805   2014            German Khan   100          Russia         RUS
# 824   2014           Gleb Fetisov  1210          Russia         RUS
# 1070  2014            Jan Kulczyk   430          Poland         POL
# 1311  2014           Kenny Troutt  1284   United States         USA
# 1617  2014          Masayoshi Son    42           Japan         JPN
# 1628  2014      Mehmet Karamehmet  1154          Turkey         TUR
# 1690  2014        Mikhail Fridman    47          Russia         RUS
# 1731  2014            Murat Vargi  1565          Turkey         TUR
# 1740  2014         Naguib Sawiris   609           Egypt         EGY
# 1741  2014           Najib Mikati   520         Lebanon         LBN
# 1790  2014           Onsi Sawiris   731           Egypt         EGY
# 1906  2014             Pyotr Aven   227          Russia         RUS
# 1987  2014             Richard Li   931       Hong Kong         HKG
# 2092  2014           Rostam Azizi  1565        Tanzania         TZA
# 2305  2014           Sunil Mittal   244           India         IND
# 2307  2014         Surin Upatkoon  1284        Thailand         THA
# 2322  2014            Taha Mikati   520         Lebanon         LBN
# 2453  2014  Vladimir Yevtushenkov   141          Russia         RUS
# 2466  2014      Walter Scott, Jr.   580   United States         USA
# 2474  2014              Wang Jing  1210           China         CHN
# 2552  2014            Xavier Niel   162          France         FRA
# 2564  2014      Yasumitsu Shigeta   663           Japan         JPN
#
#       networthusbillion   selfmade              typeofwealth gender   age  \
# 71                  2.1  self-made  privatized and resources   male  55.0
# 87                  8.8  self-made  privatized and resources   male  51.0
# 112                18.6  self-made  privatized and resources   male  60.0
# 137                11.3  self-made       founder non-finance   male  75.0
# 153                 1.7  self-made  privatized and resources   male  52.0
# 155                 1.2  self-made  privatized and resources   male  48.0
# 348                72.0  self-made  privatized and resources   male  74.0
# 450                 1.8  self-made       founder non-finance   male  64.0
# 531                 6.0  self-made  privatized and resources   male  55.0
# 694                 2.9  self-made  privatized and resources   male  58.0
# 805                11.3  self-made  privatized and resources   male  52.0
# 824                 1.4  self-made                 executive   male  47.0
# 1070                3.6  self-made  privatized and resources   male  64.0
# 1311                1.3  self-made       founder non-finance   male  66.0
# 1617               18.4  self-made       founder non-finance   male  56.0
# 1628                1.5  self-made                 executive   male  69.0
# 1690               17.6  self-made  privatized and resources   male  49.0
# 1731                1.0  self-made       founder non-finance   male  66.0
# 1740                2.8  inherited                 inherited   male  59.0
# 1741                3.1  self-made  privatized and resources   male  58.0
# 1790                2.4  self-made       founder non-finance   male  84.0
# 1906                6.1  self-made  privatized and resources   male  58.0
# 1987                1.9  inherited                 inherited   male  47.0
# 2092                1.0  self-made                 executive   male  49.0
# 2305                5.7  self-made       founder non-finance   male  56.0
# 2307                1.3  self-made                 executive   male  64.0
# 2322                3.1  self-made  privatized and resources   male  69.0
# 2453                9.0  self-made  privatized and resources   male  65.0
# 2466                2.9  self-made                 executive   male  82.0
# 2474                1.4  self-made                 executive   male  41.0
# 2552                8.2  self-made       founder non-finance   male  46.0
# 2564                2.6  self-made       founder non-finance   male  49.0
#
#       ...           relationshiptocompany foundingdate gdpcurrentus  \
# 71    ...                         founder       2005.0          NaN
# 87    ...                         founder       1989.0          NaN
# 112   ...                         founder       1999.0          NaN
# 137   ...                         founder       1984.0          NaN
# 153   ...  supervisory board or directors       1989.0          NaN
# 155   ...                         founder       1991.0          NaN
# 348   ...                         founder       1990.0          NaN
# 450   ...                         founder       1987.0          NaN
# 531   ...                         founder       1997.0          NaN
# 694   ...                         founder       1999.0          NaN
# 805   ...                         founder       1989.0          NaN
# 824   ...                           owner       1989.0          NaN
# 1070  ...                         founder       1988.0          NaN
# 1311  ...                         founder       1988.0          NaN
# 1617  ...                     founder/CEO       1981.0          NaN
# 1628  ...                        chairman       1923.0          NaN
# 1690  ...                         founder       1989.0          NaN
# 1731  ...                         founder       1993.0          NaN
# 1740  ...                        relation       1950.0          NaN
# 1741  ...                         founder       1982.0          NaN
# 1790  ...                         founder       1950.0          NaN
# 1906  ...           chairman of the board       1989.0          NaN
# 1987  ...                        relation       1971.0          NaN
# 2092  ...                        investor       1999.0          NaN
# 2305  ...                         founder       1980.0          NaN
# 2307  ...                           owner       1983.0          NaN
# 2322  ...                         founder       1982.0          NaN
# 2453  ...                Chairman/founder       1993.0          NaN
# 2466  ...                      former CEO       1884.0          NaN
# 2474  ...                        chairman       1995.0          NaN
# 2552  ...                         founder       1999.0          NaN
# 2564  ...                         founder       1988.0          NaN
#
#                          sourceofwealth  \
# 71                oil, telecom, banking
# 87                oil, banking, telecom
# 112         steel, telecom, investments
# 137                             telecom
# 153               oil, telecom, banking
# 155   telecom, oil service, real estate
# 348                             telecom
# 450                             telecom
# 531                             telecom
# 694           iron ore, steel, telecoms
# 805               oil, banking, telecom
# 824                    telecom, finance
# 1070                 telecom, oil, beer
# 1311                 telecommunications
# 1617                  internet, telecom
# 1628               telecom, diversified
# 1690              oil, banking, telecom
# 1731                            telecom
# 1740                            telecom
# 1741                            telecom
# 1790              construction, telecom
# 1906              oil, banking, telecom
# 1987                           telecoms
# 2092               telecom, investments
# 2305                            telecom
# 2307       telecoms/lotteries/insurance
# 2322                            telecom
# 2453                            telecom
# 2466              construction, telecom
# 2474                 telecommunications
# 2552                  internet, telecom
# 2564                     mobile telecom
#
#                                                   notes  \
# 71                                                  NaN
# 87                                                  NaN
# 112                                                 NaN
# 137                                                 NaN
# 153                                                 NaN
# 155                                 connected to Lukoil
# 348                                                 NaN
# 450   not only won FCC's lottery for setting up cabl...
# 531   won a mobile phone licence due to payments to ...
# 694                                                 NaN
# 805                                                 NaN
# 824                                                 NaN
# 1070                                                NaN
# 1311                                                NaN
# 1617                                                NaN
# 1628                                                NaN
# 1690                                                NaN
# 1731                                                NaN
# 1740                              inherited from father
# 1741  PM of Lebanon from June 2001 to Feb 2014 and i...
# 1790  Some evidence connected money, but less eviden...
# 1906                                                NaN
# 1987                              inherited from father
# 2092                                                NaN
# 2305                                                NaN
# 2307                                                NaN
# 2322                            PM of Lebanon's brother
# 2453                                   Bashneft scandal
# 2466  Childhood friend of Warren Buffet, sits on Ber...
# 2474                                                NaN
# 2552                                                NaN
# 2564  Had $42 billion in 1999, lost most of it in do...
#
#                                                  notes2  \
# 71                                                  NaN
# 87                                                  NaN
# 112                                                 NaN
# 137                                                 NaN
# 153                                                 NaN
# 155                                                 NaN
# 348                                                 NaN
# 450                                                 NaN
# 531                                                 NaN
# 694                                                 NaN
# 805                                                 NaN
# 824                                                 NaN
# 1070                                                NaN
# 1311                                                NaN
# 1617                                                NaN
# 1628                                                NaN
# 1690                                                NaN
# 1731                                                NaN
# 1740                                                NaN
# 1741                                                NaN
# 1790                                                NaN
# 1906                                                NaN
# 1987                                                NaN
# 2092                                                NaN
# 2305                                                NaN
# 2307                                                NaN
# 2322                                                NaN
# 2453                                                NaN
# 2466                                                NaN
# 2474  involved in Nicaragua projected / some questio...
# 2552                                                NaN
# 2564                                                NaN
#
#                                                  source  \
# 71       http://en.wikipedia.org/wiki/Alexander_Knaster
# 87        http://en.wikipedia.org/wiki/Alexey_Kuzmichev
# 112                               http://usm-group.com/
# 137        http://en.wikipedia.org/wiki/Ananda_Krishnan
# 153       http://www.forbes.com/profile/andrei-kosogov/
# 155       http://www.forbes.com/profile/andrei-kuzyaev/
# 348   http://www.ozy.com/provocateurs/carlos-slims-w...
# 450            http://en.wikipedia.org/wiki/Craig_McCaw
# 531          http://en.wikipedia.org/wiki/Denis_O'Brien
# 694   http://en.wikipedia.org/wiki/Farhad_Moshiri_(b...
# 805            http://en.wikipedia.org/wiki/German_Khan
# 824         http://www.forbes.com/profile/gleb-fetisov/
# 1070           http://en.wikipedia.org/wiki/Jan_Kulczyk
# 1311        http://www.forbes.com/profile/kenny-troutt/
# 1617         http://en.wikipedia.org/wiki/Masayoshi_Son
# 1628  http://en.wikipedia.org/wiki/Mehmet_Emin_Karam...
# 1690     http://www.forbes.com/profile/mikhail-fridman/
# 1731         http://www.forbes.com/profile/murat-vargi/
# 1740        http://en.wikipedia.org/wiki/Sawiris_Family
# 1741          http://en.wikipedia.org/wiki/Najib_Mikati
# 1790        http://en.wikipedia.org/wiki/Sawiris_Family
# 1906            http://en.wikipedia.org/wiki/Pyotr_Aven
# 1987            http://en.wikipedia.org/wiki/Richard_Li
# 2092        http://www.forbes.com/profile/rostam-azizi/
# 2305          http://en.wikipedia.org/wiki/Sunil_Mittal
# 2307      http://www.forbes.com/profile/surin-upatkoon/
# 2322          http://en.wikipedia.org/wiki/Najib_Mikati
# 2453  http://www.sistema.com/about-sistema/corporate...
# 2466     http://en.wikipedia.org/wiki/Walter_Scott,_Jr.
# 2474         http://www.forbes.com/profile/wang-jing-3/
# 2552           http://en.wikipedia.org/wiki/Xavier_Niel
# 2564   http://www.forbes.com/profile/yasumitsu-shigeta/
#
#                                                source_2  \
# 71     http://www.forbes.com/profile/alexander-knaster/
# 87      http://www.forbes.com/profile/alexei-kuzmichev/
# 112         https://en.wikipedia.org/wiki/Metalloinvest
# 137   http://www.bloomberg.com/research/stocks/priva...
# 153   http://www.bloomberg.com/research/stocks/priva...
# 155          http://www.pfpg.ru/en/company/history.html
# 348                                                 NaN
# 450   http://community.seattletimes.nwsource.com/arc...
# 531   http://www.irishtimes.com/news/ireland/irish-n...
# 694   http://www.bloomberg.com/news/articles/2012-04...
# 805   http://luxatic.com/german-khan-the-oligarch-be...
# 824   Putin's daring stroke abroad masks risks at ho...
# 1070  https://books.google.com/books?id=jP6QAwAAQBAJ...
# 1311  http://www.bloomberg.com/bw/stories/1998-04-19...
# 1617      http://www.softbank.jp/en/corp/about/history/
# 1628  http://en.wikipedia.org/wiki/%C3%87ukurova_Hol...
# 1690  The Autumn Of the Oligarchs The New York Times...
# 1731              http://en.wikipedia.org/wiki/Turkcell
# 1740                                                NaN
# 1741  http://www.bbc.com/news/world-middle-east-1227...
# 1790  http://www.euroasiaindustry.com/article/sawiri...
# 1906  The Autumn Of the Oligarchs The New York Times...
# 1987                                                NaN
# 2092      http://en.wikipedia.org/wiki/Vodacom_Tanzania
# 2305  http://timesofindia.indiatimes.com/topic/Sunil...
# 2307  http://www.intouchcompany.com/as_milestone_en.asp
# 2322  http://www.bbc.com/news/world-middle-east-1227...
# 2453  http://en.wikipedia.org/wiki/Vladimir_Yevtushe...
# 2466    http://en.wikipedia.org/wiki/Kiewit_Corporation
# 2474    http://www.xinwei.com.cn/en/about/about_us.html
# 2552  http://www.ft.com/intl/cms/s/2/22167134-b24a-1...
# 2564                                                NaN
#
#                                                source_3 source_4
# 71    http://www.bloomberg.com/profiles/people/19070...      NaN
# 87    A frosty relationship that failed to thaw; Bas...      NaN
# 112   Russia and the Rams Oligarchy: How the Rams, c...      NaN
# 137      http://www.forbes.com/profile/ananda-krishnan/      NaN
# 153                                                 NaN      NaN
# 155   http://www.bloomberg.com/research/stocks/priva...      NaN
# 348                                                 NaN      NaN
# 450                                                 NaN      NaN
# 531                                                 NaN      NaN
# 694                                                 NaN      NaN
# 805                                                 NaN      NaN
# 824                                                 NaN      NaN
# 1070  Jan Kulczyk, 65, became richest man in Poland ...      NaN
# 1311                                                NaN      NaN
# 1617      http://www.softbank.jp/en/corp/about/message/      NaN
# 1628  http://www.cukurovaholding.com.tr/Kisaca-Cukur...      NaN
# 1690                                                NaN      NaN
# 1731  http://www.bloomberg.com/research/stocks/priva...      NaN
# 1740                                                NaN      NaN
# 1741  Lebanese fund takes Sainsbury's shares to chec...      NaN
# 1790                                                NaN      NaN
# 1906                                                NaN      NaN
# 1987                                                NaN      NaN
# 2092  http://www.thecitizen.co.tz/News/Rostam--Dewji...      NaN
# 2305                                                NaN      NaN
# 2307                                                NaN      NaN
# 2322  Lebanese fund takes Sainsbury's shares to chec...      NaN
# 2453  Zinc giant leads new wave of Russian firms to ...      NaN
# 2466  http://www.bizjournals.com/seattle/morning_cal...      NaN
# 2474  http://www.reuters.com/article/us-china-canal-...      NaN
# 2552                                                NaN      NaN
# 2564                                                NaN      NaN
#
# [32 rows x 30 columns]

# %% [markdown]
# ## 4) Πόσοι είναι οι άνδρες και πόσες οι γυναίκες? Ποια είναι η μέση διαφορά του πλούτου τους?
#
# > **Συμβουλή:** Το δεύτερο μισό της ερώτησης χρειάζεται `groupby`, το πρώτο όχι.

# %%
df['gender'].value_counts()
# Out:
# male              2328
# female             249
# married couple       3
# Name: gender, dtype: int64

# %%
df.groupby('citizenship') ['gender'].value_counts()
# Out:
# citizenship     gender
# Algeria         male        1
# Angola          female      1
# Argentina       male        8
#                 female      3
# Australia       male       29
#                          ...
# United Kingdom  female      4
# United States   male      794
#                 female    109
# Venezuela       male        7
# Vietnam         male        1
# Name: gender, Length: 106, dtype: int64

# %%
df.sort_values(by='citizenship', ascending = False)[:10]
# Out:
#       year                 name  rank    citizenship countrycode  \
# 1863  2014      Pham Nhat Vuong  1092        Vietnam         VNM
# 856   1996     Gustavo Cisneros   382      Venezuela         VEN
# 857   2001     Gustavo Cisneros    64      Venezuela         VEN
# 1497  1996      Lorenzo Mendoza   320      Venezuela         VEN
# 1498  2001      Lorenzo Mendoza    82      Venezuela         VEN
# 1499  2014      Lorenzo Mendoza   446      Venezuela         VEN
# 858   2014     Gustavo Cisneros   375      Venezuela         VEN
# 1249  2014  Juan Carlos Escotet  1154      Venezuela         VEN
# 1213  2014         Jon Huntsman  1465  United States         USA
# 1212  2001         Jon Huntsman   104  United States         USA
#
#       networthusbillion   selfmade         typeofwealth gender   age  ...  \
# 1863                1.6  self-made    self-made finance   male  45.0  ...
# 856                 1.1  inherited            inherited   male  50.0  ...
# 857                 5.3  inherited            inherited   male  55.0  ...
# 1497                1.3  inherited            inherited   male  30.0  ...
# 1498                4.5  inherited            inherited   male  35.0  ...
# 1499                3.5  inherited            inherited   male  48.0  ...
# 858                 4.0  inherited            inherited   male  68.0  ...
# 1249                1.5  self-made    self-made finance   male  54.0  ...
# 1213                1.1  self-made  founder non-finance   male  76.0  ...
# 1212                3.8  self-made  founder non-finance   male  63.0  ...
#
#      relationshiptocompany foundingdate  gdpcurrentus  sourceofwealth  \
# 1863               founder       1993.0           NaN     real estate
# 856               relation       1929.0  6.825859e+10             NaN
# 857               relation       1929.0  1.229100e+11             NaN
# 1497              relation       1941.0  6.825859e+10             NaN
# 1498              relation       1941.0  1.229100e+11             NaN
# 1499              relation       1941.0           NaN       beverages
# 858               relation       1929.0           NaN           media
# 1249               founder       1992.0           NaN         banking
# 1213               founder       1982.0           NaN       chemicals
# 1212               founder       1982.0  1.062180e+13             NaN
#
#                                                   notes  notes2  \
# 1863                                                NaN     NaN
# 856   father gained Pepsi concession in 1940 and con...     NaN
# 857   father gained Pepsi concession in 1940 and con...     NaN
# 1497  largest private venezuelan corporation, critic...     NaN
# 1498  largest private venezuelan corporation, critic...     NaN
# 1499  largest private venezuelan corporation, critic...     NaN
# 858   father gained Pepsi concession in 1940 and con...     NaN
# 1249                                                NaN     NaN
# 1213                                                NaN     NaN
# 1212                                                NaN     NaN
#
#                                                  source  \
# 1863     http://www.forbes.com/profile/pham-nhat-vuong/
# 856       http://en.wikipedia.org/wiki/Gustavo_Cisneros
# 857       http://en.wikipedia.org/wiki/Gustavo_Cisneros
# 1497        http://en.wikipedia.org/wiki/Empresas_Polar
# 1498        http://en.wikipedia.org/wiki/Empresas_Polar
# 1499        http://en.wikipedia.org/wiki/Empresas_Polar
# 858       http://en.wikipedia.org/wiki/Gustavo_Cisneros
# 1249  http://www.forbes.com/profile/juan-carlos-esco...
# 1213        http://www.forbes.com/profile/jon-huntsman/
# 1212        http://www.forbes.com/profile/jon-huntsman/
#
#                                                source_2  \
# 1863  http://vingroup.net/en-US/Introduction/Overvie...
# 856   http://www.miamiherald.com/news/business/biz-m...
# 857   http://www.miamiherald.com/news/business/biz-m...
# 1497  http://empresaspolar.com/nuestra-historia/cron...
# 1498  http://empresaspolar.com/nuestra-historia/cron...
# 1499  http://empresaspolar.com/nuestra-historia/cron...
# 858   http://www.miamiherald.com/news/business/biz-m...
# 1249  http://www.bloomberg.com/news/articles/2012-12...
# 1213  http://www.foxbusiness.com/markets/2014/10/03/...
# 1212  http://www.foxbusiness.com/markets/2014/10/03/...
#
#                                                source_3 source_4
# 1863  Vietnam's striking income gap; A few Rolls-Roy...      NaN
# 856                                                 NaN      NaN
# 857                                                 NaN      NaN
# 1497  http://www.eluniversal.com/economia/151027/ceo...      NaN
# 1498  http://www.eluniversal.com/economia/151027/ceo...      NaN
# 1499  http://www.eluniversal.com/economia/151027/ceo...      NaN
# 858                                                 NaN      NaN
# 1249                                                NaN      NaN
# 1213                                                NaN      NaN
# 1212                                                NaN      NaN
#
# [10 rows x 30 columns]

# %%
df['citizenship'].value_counts()
# Out:
# United States    903
# Germany          160
# China            153
# Russia           119
# Japan             96
#                 ...
# Romania            1
# Bahrain            1
# Bermuda            1
# Georgia            1
# Uganda             1
# Name: citizenship, Length: 73, dtype: int64

# %%
df.groupby('gender')['networthusbillion'].mean()
# Out:
# gender
# female            3.819277
# male              3.516881
# married couple    1.300000
# Name: networthusbillion, dtype: float64

# %%
male = df[df['gender'] == 'male']
female = df[df['gender'] == 'female']

# %%
male['networthusbillion'].mean() - female['networthusbillion'].mean()
# Out:
# -0.3023956651347586

# %% [markdown]
# ## 5) Ποιος είναι ο φτωχότερος δισεκατομμυριούχος? Ποιοι είναι οι 10 φτωχότεροι?

# %%
df.sort_values(by='networthusbillion')[:1]
# Out:
#       year               name  rank citizenship countrycode  \
# 2316  2014  T.S. Kalyanaraman  1565       India         IND
#
#       networthusbillion   selfmade         typeofwealth gender   age  ...  \
# 2316                1.0  self-made  founder non-finance   male  66.0  ...
#
#      relationshiptocompany foundingdate gdpcurrentus  sourceofwealth  notes  \
# 2316               founder       1993.0          NaN         jewelry    NaN
#
#       notes2                                          source  \
# 2316     NaN  http://en.wikipedia.org/wiki/T.S._Kalyanaraman
#
#                                                source_2 source_3 source_4
# 2316  http://www.bloomberg.com/news/articles/2013-01...      NaN      NaN
#
# [1 rows x 30 columns]

# %%
df.sort_values(by='networthusbillion')[:10]
# Out:
#       year                        name  rank    citizenship countrycode  \
# 2316  2014           T.S. Kalyanaraman  1565          India         IND
# 1202  2001                   John Todd   490    New Zealand         NZL
# 482   2014               Dariusz Milek  1565         Poland         POL
# 1204  2014           John Van Lieshout  1565      Australia         AUS
# 2174  2014              Serhiy Tihipko  1565        Ukraine         UKR
# 2547  2014                 Wu Chung-Yi  1565         Taiwan      Taiwan
# 122   2001  Amalia Lacroze de Fortabat   490      Argentina         ARG
# 1019  1996                 Jack Taylor   421  United States         USA
# 475   1996                 Daniel Ziff   419  United States         USA
# 2123  1996                 Saleh Kamel   403   Saudi Arabia         SAU
#
#       networthusbillion   selfmade         typeofwealth  gender   age  ...  \
# 2316                1.0  self-made  founder non-finance    male  66.0  ...
# 1202                1.0  inherited            inherited    male   NaN  ...
# 482                 1.0  self-made    self-made finance    male  46.0  ...
# 1204                1.0  self-made    self-made finance    male  68.0  ...
# 2174                1.0  self-made    self-made finance    male  54.0  ...
# 2547                1.0  self-made            executive    male  55.0  ...
# 122                 1.0  inherited            inherited  female   NaN  ...
# 1019                1.0  self-made  founder non-finance    male   0.0  ...
# 475                 1.0  inherited            inherited    male  24.0  ...
# 2123                1.0  self-made    self-made finance    male  54.0  ...
#
#      relationshiptocompany foundingdate  gdpcurrentus        sourceofwealth  \
# 2316               founder       1993.0           NaN               jewelry
# 1202              relation       1929.0  5.387259e+10                   NaN
# 482                founder       1989.0           NaN   real estate, retail
# 1204               founder          NaN           NaN           real estate
# 2174               founder       1992.0           NaN  banking, agriculture
# 2547              investor       1991.0           NaN         manufacturing
# 122               relation       1926.0  2.690000e+11                   NaN
# 1019               founder       1957.0  8.100200e+12                   NaN
# 475               relation       1927.0  8.100200e+12                   NaN
# 2123               founder       1969.0  1.577430e+11                   NaN
#
#                notes  notes2  \
# 2316             NaN     NaN
# 1202  3rd generation     NaN
# 482              NaN     NaN
# 1204             NaN     NaN
# 2174             NaN     NaN
# 2547             NaN     NaN
# 122            widow     NaN
# 1019             NaN     NaN
# 475   3rd generation     NaN
# 2123             NaN     NaN
#
#                                                  source  \
# 2316     http://en.wikipedia.org/wiki/T.S._Kalyanaraman
# 1202  http://en.wikipedia.org/wiki/Todd_Corporation#...
# 482     http://pl.wikipedia.org/wiki/Dariusz_Mi%C5%82ek
# 1204   http://www.forbes.com/profile/john-van-lieshout/
# 2174      http://www.forbes.com/profile/serhiy-tihipko/
# 2547         http://www.forbes.com/profile/wu-chung-yi/
# 122   http://en.wikipedia.org/wiki/Mar%C3%ADa_Amalia...
# 1019        http://en.wikipedia.org/wiki/Jack_C._Taylor
# 475             http://en.wikipedia.org/wiki/Ziff_Davis
# 2123  http://en.wikipedia.org/wiki/Saleh_Abdullah_Kamel
#
#                                                source_2  \
# 2316  http://www.bloomberg.com/news/articles/2013-01...
# 1202  http://en.wikipedia.org/wiki/Bryan_Todd_(New_Z...
# 482        http://www.forbes.com/profile/dariusz-milek/
# 1204  The Courier Mail (Australia) July 25, 2015 Sat...
# 2174            http://en.wikipedia.org/wiki/PrivatBank
# 2547  http://en.wikipedia.org/wiki/Tingyi_(Cayman_Is...
# 122   Australian Financial Review February 28, 2014 ...
# 1019         http://www.forbes.com/profile/jack-taylor/
# 475   http://en.wikipedia.org/wiki/William_Bernard_Z...
# 2123  ISLAMIC BANKS TURN ATTENTION TO US MARKET The ...
#
#                                                source_3 source_4
# 2316                                                NaN      NaN
# 1202  Inside the Todd empire The New Zealand Herald ...      NaN
# 482                                                 NaN      NaN
# 1204                                                NaN      NaN
# 2174  http://www.kyivpost.com/content/business/priva...      NaN
# 2547  Tingyi-Campbell sale talks stay on track South...      NaN
# 122                                                 NaN      NaN
# 1019  FATHER AND SON WHO BUILT ENTERPRISE ACCEPT CIT...      NaN
# 475   http://www.wsj.com/articles/ziffs-shut-down-he...      NaN
# 2123                                                NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 6) Ποια είναι η πιο συχνή πηγή πλούτου? Είναι διαφορετική στους άνδρες και τις γυναίκες?
#
# > **Συμβουλή:** Ξέρετε τι κάνει το `groupby` και ξέρετε πώς μετράμε πόσες φορές υπάρχει ένα value μέσα σε ένα column. Συνδυάστε τα.

# %%
df['typeofwealth'].value_counts()[:1]
# Out:
# inherited    953
# Name: typeofwealth, dtype: int64

# %%
df.groupby('typeofwealth')['gender'].value_counts().sort_values(ascending = False)
# Out:
# typeofwealth              gender
# inherited                 male              724
# founder non-finance       male              687
# self-made finance         male              493
# privatized and resources  male              231
# inherited                 female            205
# executive                 male              184
# founder non-finance       female             25
# self-made finance         female              7
# executive                 female              6
# privatized and resources  female              5
# inherited                 married couple      2
# founder non-finance       married couple      1
# Name: gender, dtype: int64

# %%
df.groupby('citizenship') ['rank'].value_counts().sort_values(ascending = False)
# Out:
# citizenship    rank
# United States  869     25
#                490     24
#                452     21
#                1465    20
#                421     20
#                        ..
# Israel         520      1
#                490      1
#                393      1
#                392      1
# Vietnam        1092     1
# Name: rank, Length: 1508, dtype: int64

# %%
df.groupby('typeofwealth')['citizenship'].value_counts().sort_values(ascending = False)
# Out:
# typeofwealth              citizenship
# inherited                 United States     307
# founder non-finance       United States     298
# self-made finance         United States     203
# inherited                 Germany           106
# privatized and resources  Russia             79
#                                            ...
# executive                 Czech Republic      1
#                           Egypt               1
#                           Indonesia           1
#                           Ireland             1
# self-made finance         Vietnam             1
# Name: citizenship, Length: 224, dtype: int64

# %% [markdown]
# ## 7) Ποιες εταιρίες έχουν τους περισσότερους δισεκατομμυριούχους? Κάντε ένα γράφημα με τους top 5. ένα horizontal bar graph.
#
# > **Συμβουλή:** Πρώτα απαντήστε στην ερώτηση και μετά δοκιμάστε το `.plot()` στο τέλος.
# >
# > **Συμβουλή:** Μπορείτε να δοκιμάσετε το `.head()` αντί για όλο το `df`
# >
# > **Συμβουλή:** Μπορεί να σκέφτεστε ότι πρέπει να κάνετε `groupby`, αλλά υπάρχει ποιο εύκολος τρόπος να μετρήσετε!

# %%
df['company'].value_counts().head(5).sort_values().plot(kind='barh')

# %%
df['company'].value_counts().head(5).sort_values()
# Out:
# Microsoft        11
# SAP AG           12
# Hyatt            15
# Campbell Soup    16
# Walmart          18
# Name: company, dtype: int64

# %% [markdown]
# ## 8) Πόσα λεφτά έχουν όλοι οι billionaires συνολικά?

# %%
companies = ["Cargill", "Walmart", "S. C. Johnson & Son", "Oetker-Gruppe", "Hyatt"]
total_bill = 0
for company in companies:
    df_companies = df[df['company'] == company]
    df_copanies_sum = df_companies['networthusbillion'].sum()
    total_bill = total_bill + df_copanies_sum
print(total_bill)
# Out:
# 390.3999999999999

# %% [markdown]
# ## 9) Ποιες είναι οι top 3 χώρες στις οποίες οι billionaires έχουν τα λεφτά τους?
#
# Δεν ρωτάω ποια χώρα έχει τους περισότερους billionaires, αλλά το συνολικό ποσό των χρημάτων ανά χώρα.
#
# > **Συμβουλή:** Σκεφτείτε ότι πρώτα πρέπει να οργανώσετε ανά χώρα, μετά να βρείτε το net worth που έχουν και μετά όλα αυτά μαζί.

# %%
df.groupby('citizenship')['networthusbillion'].sum().sort_values(ascending = False).head(5)
# Out:
# citizenship
# United States    3542.1
# Germany           671.0
# Russia            434.9
# China             377.1
# Hong Kong         338.2
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ## 10) Πόσο χρονών είναι ο μέσος billionaire? Πόσο χρονών είναι οι self made vs. non self made?

# %%
round(df['age'].mean())
# Out:
# 57

# %%
[df[df['selfmade'] == 'self-made']['age'].mean() , df[df['selfmade'] != 'self-made']['age'].mean()]
# Out:
# [59.47457627118644, 53.85474860335196]

# %% [markdown]
# ## 11) Ποιοι είναι οι νεότεροι billionaires? Ποιοι οι γηραιότεροι? Φτιάξτε ένα γράφημα με τη διασπορά των ηλικιών.

# %%
df.sort_values('age',ascending = True)['name'][:10]
# Out:
# 1355             Kunio Busujima
# 1297            Kenichi Mabuchi
# 1180                John Latsis
# 1309            Kenneth Tuchman
# 163             Andrew Gotianun
# 1075    Jay and Arthur Pritzker
# 1465            Liem Sioe Liong
# 611                Edmond Safra
# 1073          Jassim Al-Kharafi
# 741          Freudenberg family
# Name: name, dtype: object

# %%
df.sort_values('age',ascending = False)['name'][:10]
# Out:
# 516       David Rockefeller, Sr.
# 1277               Karl Wlaschek
# 1328              Kirk Kerkorian
# 921                Henry Hillman
# 666           Erika Pohl-Stroher
# 1275               Karl Albrecht
# 181            Anne Cox Chambers
# 2292           Sulaiman Al Rajhi
# 2530       William Moncrief, Jr.
# 119     Aloysio de Andrade Faria
# Name: name, dtype: object

# %%
df['age'].plot(kind='hist')

# %% [markdown]
# ## 12) Φτιάξτε ένα scatterplot που να σχετίζει το net worth σε σχέση με την ηλικία τους.

# %%
df.plot(kind='scatter', x='networthusbillion', y='age')

# %% [markdown]
# ## 13) Φτιάξτε ένα γράφημα με τους top 10 πλουσιότερους billionaires

# %%
df.sort_values(by='networthusbillion', ascending = False)[:10].plot(kind='bar', y='networthusbillion', x='name')
